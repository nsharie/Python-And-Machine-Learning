# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'redwine.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
import pandas as pd
from PyQt5.QtWidgets import *
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
import numpy as np


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1395, 929)
        Form.setStyleSheet("background-color: rgb(166, 200, 185);")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(480, 30, 441, 61))
        self.label.setStyleSheet("color:rgb(0, 0, 255);\n"
"font: 75 28pt \"Times New Roman\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(90, 180, 131, 41))
        self.label_2.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(550, 180, 151, 41))
        self.label_3.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(980, 180, 111, 41))
        self.label_4.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(90, 310, 161, 31))
        self.label_5.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(560, 310, 101, 31))
        self.label_6.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(980, 300, 211, 31))
        self.label_7.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(90, 420, 211, 31))
        self.label_8.setStyleSheet("colr:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(560, 420, 81, 31))
        self.label_9.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(990, 410, 71, 31))
        self.label_10.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(100, 520, 101, 31))
        self.label_11.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(560, 510, 81, 41))
        self.label_12.setStyleSheet("colr:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_12.setObjectName("label_12")
        self.submit = QtWidgets.QPushButton(Form)
        self.submit.setGeometry(QtCore.QRect(610, 620, 151, 41))
        self.submit.setStyleSheet("border-color: qradialgradient(spread:pad, cx:0.5, cy:0.5, radius:0.5, fx:0.5, fy:0.5, stop:0 rgba(255, 255, 255, 255), stop:0.1 rgba(255, 255, 255, 255), stop:0.2 rgba(255, 176, 176, 167), stop:0.3 rgba(255, 151, 151, 92), stop:0.4 rgba(255, 125, 125, 51), stop:0.5 rgba(255, 76, 76, 205), stop:0.52 rgba(255, 76, 76, 205), stop:0.6 rgba(255, 180, 180, 84), stop:1 rgba(255, 255, 255, 0));\n"
"background-color: rgb(94, 129, 255);\n"
"font: 75 20pt \"Times New Roman\";")
        self.submit.setObjectName("submit")
        self.quality = QtWidgets.QLabel(Form)
        self.quality.setGeometry(QtCore.QRect(620, 730, 131, 41))
        self.quality.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 20pt \"Times New Roman\";")
        self.quality.setObjectName("quality")
        self.fixed_acidity = QtWidgets.QLineEdit(Form)
        self.fixed_acidity.setGeometry(QtCore.QRect(320, 180, 141, 41))
        self.fixed_acidity.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.fixed_acidity.setObjectName("fixed_acidity")
        self.volatile_acidity = QtWidgets.QLineEdit(Form)
        self.volatile_acidity.setGeometry(QtCore.QRect(750, 180, 141, 41))
        self.volatile_acidity.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.volatile_acidity.setObjectName("volatile_acidity")
        self.citric_acid = QtWidgets.QLineEdit(Form)
        self.citric_acid.setGeometry(QtCore.QRect(1210, 180, 141, 41))
        self.citric_acid.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.citric_acid.setObjectName("citric_acid")
        self.residual_sugar = QtWidgets.QLineEdit(Form)
        self.residual_sugar.setGeometry(QtCore.QRect(320, 300, 141, 41))
        self.residual_sugar.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.residual_sugar.setObjectName("residual_sugar")
        self.chlorides = QtWidgets.QLineEdit(Form)
        self.chlorides.setGeometry(QtCore.QRect(750, 300, 141, 41))
        self.chlorides.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.chlorides.setObjectName("chlorides")
        self.sulphur_dioxide = QtWidgets.QLineEdit(Form)
        self.sulphur_dioxide.setGeometry(QtCore.QRect(1210, 290, 141, 41))
        self.sulphur_dioxide.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.sulphur_dioxide.setObjectName("sulphur_dioxide")
        self.total_sulphur = QtWidgets.QLineEdit(Form)
        self.total_sulphur.setGeometry(QtCore.QRect(320, 410, 141, 41))
        self.total_sulphur.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.total_sulphur.setObjectName("total_sulphur")
        self.density = QtWidgets.QLineEdit(Form)
        self.density.setGeometry(QtCore.QRect(750, 410, 141, 41))
        self.density.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.density.setObjectName("density")
        self.ph = QtWidgets.QLineEdit(Form)
        self.ph.setGeometry(QtCore.QRect(1210, 400, 141, 41))
        self.ph.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.ph.setObjectName("ph")
        self.sulphates = QtWidgets.QLineEdit(Form)
        self.sulphates.setGeometry(QtCore.QRect(320, 510, 141, 41))
        self.sulphates.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.sulphates.setObjectName("sulphates")
        self.alcohol = QtWidgets.QLineEdit(Form)
        self.alcohol.setGeometry(QtCore.QRect(750, 510, 141, 41))
        self.alcohol.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.alcohol.setObjectName("alcohol")
        self.submit.clicked.connect(self.redwineprediction)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def redwineprediction(self):
        # extracting the dataset
        path = "C:/Users/INZAMAM/Desktop/intership/KNN/Winequalitydatatset - 2/Wine-Quality-Dataset-master/winequalityred.csv"
        data = pd.read_csv(path)
        
        # filling the empty or Nan values
        median = data.fixed_acidity.median()
        data.fixed_acidity = data.fixed_acidity.fillna(median)

        median1 = data.volatile_acidity.median()
        data.volatile_acidity = data.volatile_acidity.fillna(median1)

        median2 = data.citric_acid.median()
        data.citric_acid = data.citric_acid.fillna(median2)

        median3 = data.pH.median()
        data.pH = data.pH.fillna(median3)

        median4 = data.sulphates.median()
        data.sulphates = data.sulphates.fillna(median4)
        
        # diving the dataset into input and output
        inputs = data.drop(['type','quality'],'columns')
        output = data.drop(['type','fixed_acidity','volatile_acidity','citric_acid','residual_sugar','chlorides','free_sulfur_dioxide','total_sulfur_dioxide','density','pH','sulphates','alcohol'],'columns')
        
        # training and testing the model
        x_train,x_test,y_train,y_test = train_test_split(inputs,output,train_size = 0.8,random_state = 0)
        sc = StandardScaler()
        x_train = sc.fit_transform(x_train)
        x_test = sc.transform(x_test)
        model = KNeighborsClassifier(n_neighbors = 40)
        model.fit(x_train,y_train)
        
        usr1 = self.fixed_acidity.text()
        usr2 = self.volatile_acidity.text()
        usr3 = self.citric_acid.text()
        usr4 = self.residual_sugar.text()
        usr5 = self.chlorides.text()    
        usr6 = self.sulphur_dioxide.text()
        usr7 = self.total_sulphur.text()
        usr7 = self.density.text()
        usr8 = self.ph.text()
        usr9 = self.sulphates.text()
        usr10 = self.alcohol.text()
        
        if usr1.isalpha() or usr2.isalpha() or usr3.isalpha() or usr4.isalpha() or usr5.isalpha() or usr6.isalpha() or usr7.isalpha() or usr8.isalpha() or usr9.isalpha() or usr10.isalpha():
            QMessageBox.information(None,"Invalid Details","All inputs should be specified in numbers")
        else:
            if(len(usr1) and len(usr2) and len(usr3) and len(usr4) and len(usr5) and len(usr6) and len(usr7) and len(usr8) and len(usr9) and len(usr10))>1:
                newinput = np.array([[float(usr1),float(usr2),float(usr3),float(usr4),float(usr5),float(usr6),float(usr6),float(usr7),float(usr8),float(usr9),float(usr10)]])
                newinput1 = sc.transform(newinput)
                res = model.predict(newinput1)
                res1 = str(int(res))
                self.quality.setText(res1)
            else:
                 QMessageBox.information(None,"Incomplete details","All the above fields should be filled")
                 
                
    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Predicting Red Wine Quality"))
        self.label_2.setText(_translate("Form", "Fixed Acidity"))
        self.label_3.setText(_translate("Form", "Volatile Acidity"))
        self.label_4.setText(_translate("Form", "Citric Acid"))
        self.label_5.setText(_translate("Form", "Residual Sugar"))
        self.label_6.setText(_translate("Form", "Chlorides"))
        self.label_7.setText(_translate("Form", "Free Sulphur Dioxide"))
        self.label_8.setText(_translate("Form", "Total Suphur Dioxide"))
        self.label_9.setText(_translate("Form", "Density"))
        self.label_10.setText(_translate("Form", "Ph"))
        self.label_11.setText(_translate("Form", "Sulphates"))
        self.label_12.setText(_translate("Form", "Alcohol"))
        self.submit.setText(_translate("Form", "Submit"))
        self.quality.setText(_translate("Form", "Quality"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\NAWAZ\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3377: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
