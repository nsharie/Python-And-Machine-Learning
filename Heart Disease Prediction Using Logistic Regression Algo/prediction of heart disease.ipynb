# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'heartdiseaseprediction1.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from PyQt5.QtWidgets import *
import numpy as np


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1560, 1020)
        Form.setStyleSheet("background-color: rgb(255, 245, 224);")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(470, 40, 661, 71))
        self.label.setStyleSheet("color:rgb(227, 14, 255);\n"
"font: 75 22pt \"Times New Roman\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(200, 190, 61, 41))
        self.label_2.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(610, 190, 51, 31))
        self.label_3.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(1020, 190, 151, 31))
        self.label_4.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(200, 320, 111, 41))
        self.label_5.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(610, 320, 121, 31))
        self.label_6.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(1030, 310, 101, 31))
        self.label_7.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(200, 440, 131, 31))
        self.label_8.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(620, 430, 91, 31))
        self.label_9.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(1020, 430, 161, 41))
        self.label_10.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(200, 550, 101, 41))
        self.label_11.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_11.setObjectName("label_11")
        self.submit = QtWidgets.QPushButton(Form)
        self.submit.setGeometry(QtCore.QRect(690, 880, 191, 41))
        self.submit.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 20pt \"Times New Roman\";\n"
"background-color: rgb(92, 255, 133);")
        self.submit.setObjectName("submit")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(620, 550, 111, 41))
        self.label_13.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_13.setObjectName("label_13")
        self.age = QtWidgets.QLineEdit(Form)
        self.age.setGeometry(QtCore.QRect(340, 190, 151, 41))
        self.age.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.age.setObjectName("age")
        self.sex = QtWidgets.QLineEdit(Form)
        self.sex.setGeometry(QtCore.QRect(750, 190, 171, 41))
        self.sex.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.sex.setObjectName("sex")
        self.chestpain = QtWidgets.QLineEdit(Form)
        self.chestpain.setGeometry(QtCore.QRect(1240, 190, 151, 41))
        self.chestpain.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.chestpain.setObjectName("chestpain")
        self.restingbp = QtWidgets.QLineEdit(Form)
        self.restingbp.setGeometry(QtCore.QRect(340, 310, 151, 41))
        self.restingbp.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.restingbp.setObjectName("restingbp")
        self.cholesterol = QtWidgets.QLineEdit(Form)
        self.cholesterol.setGeometry(QtCore.QRect(750, 309, 171, 41))
        self.cholesterol.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.cholesterol.setObjectName("cholesterol")
        self.fastingbs = QtWidgets.QLineEdit(Form)
        self.fastingbs.setGeometry(QtCore.QRect(1242, 300, 151, 41))
        self.fastingbs.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.fastingbs.setObjectName("fastingbs")
        self.restingecg = QtWidgets.QLineEdit(Form)
        self.restingecg.setGeometry(QtCore.QRect(340, 430, 151, 41))
        self.restingecg.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.restingecg.setObjectName("restingecg")
        self.maxhr = QtWidgets.QLineEdit(Form)
        self.maxhr.setGeometry(QtCore.QRect(750, 430, 171, 41))
        self.maxhr.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.maxhr.setObjectName("maxhr")
        self.exerciseangina = QtWidgets.QLineEdit(Form)
        self.exerciseangina.setGeometry(QtCore.QRect(1240, 420, 151, 41))
        self.exerciseangina.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.exerciseangina.setObjectName("exerciseangina")
        self.oldpeak = QtWidgets.QLineEdit(Form)
        self.oldpeak.setGeometry(QtCore.QRect(340, 549, 151, 41))
        self.oldpeak.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.oldpeak.setObjectName("oldpeak")
        self.st_slope = QtWidgets.QLineEdit(Form)
        self.st_slope.setGeometry(QtCore.QRect(750, 550, 171, 41))
        self.st_slope.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.st_slope.setObjectName("st_slope")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(140, 630, 511, 41))
        self.label_14.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";")
        self.label_14.setObjectName("label_14")
        self.label_15 = QtWidgets.QLabel(Form)
        self.label_15.setGeometry(QtCore.QRect(140, 670, 1321, 31))
        self.label_15.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";")
        self.label_15.setObjectName("label_15")
        self.label_16 = QtWidgets.QLabel(Form)
        self.label_16.setGeometry(QtCore.QRect(140, 700, 1591, 31))
        self.label_16.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";")
        self.label_16.setObjectName("label_16")
        self.label_17 = QtWidgets.QLabel(Form)
        self.label_17.setGeometry(QtCore.QRect(250, 740, 951, 21))
        self.label_17.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";")
        self.label_17.setObjectName("label_17")
        self.label_18 = QtWidgets.QLabel(Form)
        self.label_18.setGeometry(QtCore.QRect(140, 780, 621, 31))
        self.label_18.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";\n"
"")
        self.label_18.setObjectName("label_18")
        self.label_19 = QtWidgets.QLabel(Form)
        self.label_19.setGeometry(QtCore.QRect(130, 820, 1091, 31))
        self.label_19.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 16pt \"Times New Roman\";")
        self.label_19.setObjectName("label_19")
        self.result = QtWidgets.QLabel(Form)
        self.result.setGeometry(QtCore.QRect(700, 950, 441, 31))
        self.result.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.result.setObjectName("result")
        self.submit.clicked.connect(self.heartdisease)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def heartdisease(self):
        # extracting the dataset
        path = "C:\\Users\\INZAMAM\\Desktop\\intership\\Logistic\\Heart Failure Prediction\\heart.csv"
        data = pd.read_csv(path)
        
        #converting the string values into unique id or integers
        le_sex = LabelEncoder()
        le_chestpaintype = LabelEncoder()
        le_restingECG = LabelEncoder()
        le_Excerciseangina = LabelEncoder()
        le_St_Slope = LabelEncoder()

        # creating new columns for unique id values
        data['sex_n'] = le_sex.fit_transform(data['Sex'])
        data['chestpain_n'] = le_chestpaintype.fit_transform(data['ChestPainType'])
        data['restingECG_n'] = le_restingECG.fit_transform(data['RestingECG'])
        data['Exerciseangina_n'] = le_Excerciseangina.fit_transform(data['ExerciseAngina'])
        data['St_Slope_n'] = le_St_Slope.fit_transform(data['ST_Slope'])
        
        #dividing the dataset into inputs and output
        inputs = data.drop(['HeartDisease','Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],'columns')
        output = data.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope','sex_n','chestpain_n','restingECG_n','Exerciseangina_n','St_Slope_n','Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak'],'columns')
        
        #dividing the dataset into traing and testing
        x_train,x_test,y_train,y_test = train_test_split(inputs,output,test_size = 0.2,random_state = 0)
        sc = StandardScaler()
        x_train = sc.fit_transform(x_train)
        x_test = sc.transform(x_test)
        
        #creation of model and intialization
        model = SVC()
        model.fit(x_train,y_train)
        
        usr1 = self.age.text()
        usr2 = self.sex.text()
        usr3 = self.chestpain.text()
        usr4 = self.restingbp.text()
        usr5 = self.cholesterol.text()
        usr6 = self.fastingbs.text()
        usr7 = self.restingecg.text()
        usr8 = self.maxhr.text()
        usr9 = self.exerciseangina.text()
        usr10 = self.oldpeak.text()
        usr11 = self.st_slope.text()
        
        if usr1.isalpha() or usr2.isalpha() or usr3.isalpha() or usr4.isalpha() or usr5.isalpha() or usr6.isalpha() or usr7.isalpha() or usr8.isalpha() or usr9.isalpha() or usr10.isalpha() or usr11.isalpha():
            QMessageBox.information(None,"Invalid Details","All inputs should be specified in numbers")
        else:
                newinput = np.array([[usr1,usr4,usr5,usr6,usr8,usr10,usr2,usr3,usr7,usr9,usr11]])
                newinput = sc.transform(newinput)
                res = model.predict(newinput)
                #res = model.predict([[usr1,usr4,usr5,usr6,usr8,usr10,usr2,usr3,usr7,usr9,usr11]])
                if res == [1]:
                    self.result.setText('Person suffer from heart disease')
                    #print(res)
                else :
                    self.result.setText('Person does not suffer from heart disease')
                    #print(res)

    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Prediction Whether A Person Get A Heart Disease Or Not"))
        self.label_2.setText(_translate("Form", "Age"))
        self.label_3.setText(_translate("Form", "Sex"))
        self.label_4.setText(_translate("Form", "ChestPainType"))
        self.label_5.setText(_translate("Form", "RestingBP"))
        self.label_6.setText(_translate("Form", "Cholesterol"))
        self.label_7.setText(_translate("Form", "FastingBS"))
        self.label_8.setText(_translate("Form", "RestingECG"))
        self.label_9.setText(_translate("Form", "MaxHR"))
        self.label_10.setText(_translate("Form", "ExerciseAngina"))
        self.label_11.setText(_translate("Form", "Oldpeak"))
        self.submit.setText(_translate("Form", "Submit"))
        self.label_13.setText(_translate("Form", "ST_Slope"))
        self.label_14.setText(_translate("Form", "Sex: sex of the patient [M: Male, F: Female] [1 0] = [\'M\' \'F\']"))
        self.label_15.setText(_translate("Form", "ChestPainType: chest pain type [TA: Typical Angina, ATA: Atypical Angina, NAP: Non-Anginal Pain, ASY: Asymptomatic] [1 2 0 3] = [\'ATA\' \'NAP\' \'ASY\' \'TA\']"))
        self.label_16.setText(_translate("Form", "RestingECG: resting electrocardiogram results [Normal: Normal, ST: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV),"))
        self.label_17.setText(_translate("Form", " LVH: showing probable or definite left ventricular hypertrophy by Estes\' criteria] [1 2 0] = [\'Normal\' \'ST\' \'LVH\']"))
        self.label_18.setText(_translate("Form", "ExerciseAngina: exercise-induced angina [Y: Yes, N: No] [0 1] = [\'N\' \'Y\']"))
        self.label_19.setText(_translate("Form", "ST_Slope: the slope of the peak exercise ST segment [Up: upsloping, Flat: flat, Down: downsloping] [2 1 0] = [\'Up\' \'Flat\' \'Down\']"))
        self.result.setText(_translate("Form", "RESULT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\NAWAZ\AppData\Local\Temp\ipykernel_11668\3134311335.py:209: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs = data.drop(['HeartDisease','Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope'],'columns')
# C:\Users\NAWAZ\AppData\Local\Temp\ipykernel_11668\3134311335.py:210: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output = data.drop(['Sex','ChestPainType','RestingECG','ExerciseAngina','ST_Slope','sex_n','chestpain_n','restingECG_n','Exerciseangina_n','St_Slope_n','Age','RestingBP','Cholesterol','FastingBS','MaxHR','Oldpeak'],'columns')
# C:\Users\NAWAZ\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...
