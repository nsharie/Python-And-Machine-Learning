# %%
# -*- coding: utf-8 -*-

# Form implementation generated from reading ui file 'heartattach.ui'
#
# Created by: PyQt5 UI code generator 5.15.4
#
# WARNING: Any manual changes made to this file will be lost when pyuic5 is
# run again.  Do not edit this file unless you know what you are doing.


from PyQt5 import QtCore, QtGui, QtWidgets
import pandas as pd
import sklearn 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from PyQt5.QtWidgets import *


class Ui_Form(object):
    def setupUi(self, Form):
        Form.setObjectName("Form")
        Form.resize(1462, 924)
        Form.setStyleSheet("background-color: rgb(255, 253, 172);")
        self.label = QtWidgets.QLabel(Form)
        self.label.setGeometry(QtCore.QRect(580, 50, 341, 41))
        self.label.setStyleSheet("color:rgb(0, 85, 255);\n"
"font: 75 22pt \"Times New Roman\";")
        self.label.setObjectName("label")
        self.label_2 = QtWidgets.QLabel(Form)
        self.label_2.setGeometry(QtCore.QRect(140, 180, 81, 41))
        self.label_2.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_2.setObjectName("label_2")
        self.label_3 = QtWidgets.QLabel(Form)
        self.label_3.setGeometry(QtCore.QRect(600, 180, 51, 31))
        self.label_3.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_3.setObjectName("label_3")
        self.label_4 = QtWidgets.QLabel(Form)
        self.label_4.setGeometry(QtCore.QRect(1040, 180, 101, 31))
        self.label_4.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_4.setObjectName("label_4")
        self.label_5 = QtWidgets.QLabel(Form)
        self.label_5.setGeometry(QtCore.QRect(130, 280, 111, 31))
        self.label_5.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_5.setObjectName("label_5")
        self.label_6 = QtWidgets.QLabel(Form)
        self.label_6.setGeometry(QtCore.QRect(590, 270, 111, 31))
        self.label_6.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_6.setObjectName("label_6")
        self.label_7 = QtWidgets.QLabel(Form)
        self.label_7.setGeometry(QtCore.QRect(130, 360, 121, 31))
        self.label_7.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_7.setObjectName("label_7")
        self.label_8 = QtWidgets.QLabel(Form)
        self.label_8.setGeometry(QtCore.QRect(1040, 260, 101, 31))
        self.label_8.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_8.setObjectName("label_8")
        self.label_9 = QtWidgets.QLabel(Form)
        self.label_9.setGeometry(QtCore.QRect(590, 350, 121, 41))
        self.label_9.setStyleSheet("COLOR:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_9.setObjectName("label_9")
        self.label_10 = QtWidgets.QLabel(Form)
        self.label_10.setGeometry(QtCore.QRect(1050, 350, 81, 31))
        self.label_10.setStyleSheet("COLOR:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_10.setObjectName("label_10")
        self.label_11 = QtWidgets.QLabel(Form)
        self.label_11.setGeometry(QtCore.QRect(130, 440, 91, 31))
        self.label_11.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_11.setObjectName("label_11")
        self.label_12 = QtWidgets.QLabel(Form)
        self.label_12.setGeometry(QtCore.QRect(600, 440, 51, 31))
        self.label_12.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_12.setObjectName("label_12")
        self.label_13 = QtWidgets.QLabel(Form)
        self.label_13.setGeometry(QtCore.QRect(1060, 430, 61, 31))
        self.label_13.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_13.setObjectName("label_13")
        self.label_14 = QtWidgets.QLabel(Form)
        self.label_14.setGeometry(QtCore.QRect(130, 510, 61, 31))
        self.label_14.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 18pt \"Times New Roman\";")
        self.label_14.setObjectName("label_14")
        self.age = QtWidgets.QLineEdit(Form)
        self.age.setGeometry(QtCore.QRect(300, 180, 131, 41))
        self.age.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.age.setObjectName("age")
        self.sex = QtWidgets.QLineEdit(Form)
        self.sex.setGeometry(QtCore.QRect(770, 170, 131, 41))
        self.sex.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.sex.setObjectName("sex")
        self.chestpain = QtWidgets.QLineEdit(Form)
        self.chestpain.setGeometry(QtCore.QRect(1200, 170, 131, 41))
        self.chestpain.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.chestpain.setObjectName("chestpain")
        self.restingbp = QtWidgets.QLineEdit(Form)
        self.restingbp.setGeometry(QtCore.QRect(300, 270, 131, 41))
        self.restingbp.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.restingbp.setObjectName("restingbp")
        self.cholesterol = QtWidgets.QLineEdit(Form)
        self.cholesterol.setGeometry(QtCore.QRect(770, 260, 131, 41))
        self.cholesterol.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.cholesterol.setObjectName("cholesterol")
        self.fastingbs = QtWidgets.QLineEdit(Form)
        self.fastingbs.setGeometry(QtCore.QRect(1200, 250, 131, 41))
        self.fastingbs.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.fastingbs.setObjectName("fastingbs")
        self.restingecg = QtWidgets.QLineEdit(Form)
        self.restingecg.setGeometry(QtCore.QRect(300, 350, 131, 41))
        self.restingecg.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.restingecg.setObjectName("restingecg")
        self.thalach = QtWidgets.QLineEdit(Form)
        self.thalach.setGeometry(QtCore.QRect(770, 350, 131, 41))
        self.thalach.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.thalach.setObjectName("thalach")
        self.exng = QtWidgets.QLineEdit(Form)
        self.exng.setGeometry(QtCore.QRect(1200, 340, 131, 41))
        self.exng.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.exng.setObjectName("exng")
        self.oldpeak = QtWidgets.QLineEdit(Form)
        self.oldpeak.setGeometry(QtCore.QRect(300, 430, 131, 41))
        self.oldpeak.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.oldpeak.setObjectName("oldpeak")
        self.slp = QtWidgets.QLineEdit(Form)
        self.slp.setGeometry(QtCore.QRect(770, 440, 131, 41))
        self.slp.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.slp.setObjectName("slp")
        self.caa = QtWidgets.QLineEdit(Form)
        self.caa.setGeometry(QtCore.QRect(1200, 430, 131, 41))
        self.caa.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.caa.setObjectName("caa")
        self.thaal = QtWidgets.QLineEdit(Form)
        self.thaal.setGeometry(QtCore.QRect(300, 500, 131, 41))
        self.thaal.setStyleSheet("background-color: rgb(255, 255, 255);\n"
"font: 75 18pt \"Times New Roman\";")
        self.thaal.setObjectName("thaal")
        self.submit = QtWidgets.QPushButton(Form)
        self.submit.setGeometry(QtCore.QRect(630, 590, 131, 41))
        self.submit.setStyleSheet("background-color: rgb(85, 255, 127);\n"
"font: 75 24pt \"Times New Roman\";")
        self.submit.setObjectName("submit")
        self.result = QtWidgets.QLabel(Form)
        self.result.setGeometry(QtCore.QRect(630, 680, 641, 51))
        self.result.setStyleSheet("color:rgb(0, 0, 0);\n"
"font: 75 20pt \"Times New Roman\";")
        self.result.setObjectName("result")
        self.submit.clicked.connect(self.heartattach)

        self.retranslateUi(Form)
        QtCore.QMetaObject.connectSlotsByName(Form)
        
    def heartattach(self):
        path = "C:/Users/INZAMAM/Desktop/intership/Logistic/Heart attack prediction/heart.csv"
        data = pd.read_csv(path)
        
        inputs = data.drop('output','columns')
        output = data.drop(['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng','oldpeak','slp','caa','thall'],'columns')

        x_train,x_test,y_train,y_test = train_test_split(inputs,output,train_size = 0.8,random_state = 0)
        
        model = LogisticRegression()
        model.fit(x_train,y_train)
        
        usr1 = self.age.text()
        usr2 = self.sex.text()
        usr3 = self.chestpain.text()
        usr4 = self.restingbp.text()
        usr5 = self.cholesterol.text()
        usr6 = self.fastingbs.text()
        usr7 = self.restingecg.text()
        usr8 = self.thalach.text()
        usr9 = self.exng.text()
        usr10 = self.oldpeak.text()
        usr11 = self.slp.text()
        usr12 = self.caa.text()
        usr13 = self.thaal.text()
        
        if usr1.isalpha() or usr2.isalpha() or usr3.isalpha() or usr4.isalpha() or usr5.isalpha() or usr6.isalpha() or usr7.isalpha() or usr8.isalpha() or usr9.isalpha() or usr10.isalpha() or usr11.isalpha() or usr12.isalpha() or usr13.isalpha():
            QMessageBox.information(None,"Invalid Details","All inputs should be specified in numbers")
        else:
            res = model.predict([[usr1,usr2,usr3,usr4,usr5,usr6,usr7,usr8,usr9,usr10,usr11,usr12,usr13]])
            if res == [0]:
                self.result.setText('Less Chance of Heart attach')
                print(res)
            else:
                self.result.setText('High Chance of Heart attach')
                print(res)    
        
    def retranslateUi(self, Form):
        _translate = QtCore.QCoreApplication.translate
        Form.setWindowTitle(_translate("Form", "Form"))
        self.label.setText(_translate("Form", "Heart Attach Prediction"))
        self.label_2.setText(_translate("Form", "Age"))
        self.label_3.setText(_translate("Form", "Sex"))
        self.label_4.setText(_translate("Form", "ChestPain"))
        self.label_5.setText(_translate("Form", "RestingBP"))
        self.label_6.setText(_translate("Form", "Cholesterol"))
        self.label_7.setText(_translate("Form", "RestingECG"))
        self.label_8.setText(_translate("Form", "FastingBS"))
        self.label_9.setText(_translate("Form", "THALACH"))
        self.label_10.setText(_translate("Form", "EXNG"))
        self.label_11.setText(_translate("Form", "Oldpeak"))
        self.label_12.setText(_translate("Form", "SLP"))
        self.label_13.setText(_translate("Form", "CAA"))
        self.label_14.setText(_translate("Form", "Thaal"))
        self.submit.setText(_translate("Form", "Submit"))
        self.result.setText(_translate("Form", "RESULT"))


if __name__ == "__main__":
    import sys
    app = QtWidgets.QApplication(sys.argv)
    Form = QtWidgets.QWidget()
    ui = Ui_Form()
    ui.setupUi(Form)
    Form.show()
    sys.exit(app.exec_())
# Out:
# C:\Users\NAWAZ\AppData\Local\Temp\ipykernel_6176\2652809589.py:178: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   inputs = data.drop('output','columns')
# C:\Users\NAWAZ\AppData\Local\Temp\ipykernel_6176\2652809589.py:179: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   output = data.drop(['age','sex','cp','trtbps','chol','fbs','restecg','thalachh','exng','oldpeak','slp','caa','thall'],'columns')
# C:\Users\NAWAZ\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\NAWAZ\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
